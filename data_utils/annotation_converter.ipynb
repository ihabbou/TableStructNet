# %% [markdown]
# Convert data annotations

# %% [markdown]
# ```xml
# <document filename="16-0500_DK-82_1-34-9855_00006.jpg">
#   <table id="Table_1542010323591_3033">
#     <Coords points="38,36 4575,36 4575,3687 38,3687"/>
#     <cell id="TableCell_1542010826285_4408" start-row="0" end-row="0" start-col="0" end-col="0">
#       <Coords points="38,36 39,164 225,164 224,36"/>
#     </cell>
# ```

# %%
class Table: 
    def __init__(self):
        self.cells = []
    
    def __str__(self):
        return "table_id="+self.id+", \n"+\
            f"table_coords={self.coords}, \n"+\
            f"table_cells={len(self.cells)}: \n"+\
            "\n".join([str(cell) for cell in self.cells])+"\n"

class Cell:
    def __init__(self):
        pass
    def __str__(self):
        return "\tcell_id="+self.id+", \n"+\
            f"\tcell_coords={self.coords}, \n"+\
            f"\tcell_location={self.location} \n"

# %%
def parse_tables_from_xml(xml_path):
    """Parses the ICDAR2019 xml annotation into a list of objects.

    Parameters
    ----------
    xml_path : path to the ICDAR2019 xml annotation.

    Returns
    -------
    tables : a list of :ref:`Table` objects from the xml annotation.
    """
    
    from xml.dom import minidom
    xmldoc = minidom.parse(xml_path)
    
    table_objs = []

    tablelist = xmldoc.getElementsByTagName('table')
    #print("num tables:", len(tablelist))

    for table in tablelist:
        table_obj = Table()

        table_id = table.attributes['id'].value
        table_obj.id = table_id
        #print("table_id: ", table_id)

        coords = [node for node in table.childNodes 
                  if node.nodeType == table.ELEMENT_NODE][0].attributes["points"].value
        coords = tuple([tuple(map(int, point.split(','))) 
                        for point in coords.split()])
        table_obj.coords = coords
        #print("coords: ", coords)

        for cell in table.getElementsByTagName("cell"):
            cell_obj = Cell()
            cell_id = cell.attributes['id'].value
            cell_obj.id = cell_id
            #print("\tcell_id: ", cell_id)

            #start_row, end_row, start_col, end_col
            location = \
                cell.attributes["start-row"].value, \
                cell.attributes["end-row"].value, \
                cell.attributes["start-col"].value, \
                cell.attributes["end-col"].value
            location = tuple(map(int, location))
            cell_obj.location = location
            #print("\tlocation: ", start_row, end_row, start_col, end_col)
            #print("\tlocation: ", location)

            ccoords = [node for node in cell.childNodes 
                      if node.nodeType == cell.ELEMENT_NODE][0].attributes["points"].value
            ccoords = tuple([tuple(map(int, point.split(','))) 
                             for point in ccoords.split()])
            
            cell_obj.coords = ccoords
            #print("\tcoords: ", ccoords)

            table_obj.cells.append(cell_obj)
            #print()
        table_objs.append(table_obj)
        
    return table_objs

# %%
print(parse_tables_from_xml('./samples/ICDAR2019/ground_truth/cTDaR_s001.xml')[0])
# Out:
# table_id=Table_1542010323591_3033,
# table_coords=((38, 36), (4575, 36), (4575, 3687), (38, 3687)),
# table_cells=286:
# 	cell_id=TableCell_1542010826285_4408,
# 	cell_coords=((38, 36), (39, 164), (225, 164), (224, 36)),
# 	cell_location=(0, 0, 0, 0)
#
# 	cell_id=TableCell_1542010826285_4406,
# 	cell_coords=((224, 36), (225, 164), (333, 164), (333, 37)),
# 	cell_location=(0, 0, 1, 1)
#
# 	cell_id=TableCell_1542010819640_4318,
# 	cell_coords=((333, 37), (333, 164), (1195, 160), (1198, 40)),
# 	cell_location=(0, 0, 2, 2)
#
# 	cell_id=TableCell_1542010811496_4230,
# 	cell_coords=((1198, 40), (1195, 160), (1710, 159), (1709, 42)),
# 	cell_location=(0, 0, 3, 3)
#
# 	cell_id=TableCell_1542010601021_3824,
# 	cell_coords=((1709, 42), (1710, 159), (2094, 159), (2089, 44)),
# 	cell_location=(0, 0, 4, 4)
#
# 	cell_id=TableCell_1542010592332_3736,
# 	cell_coords=((2089, 44), (2094, 159), (2331, 158), (2331, 46)),
# 	cell_location=(0, 0, 5, 5)
#
# 	cell_id=TableCell_1542010583393_3648,
# 	cell_coords=((2331, 46), (2331, 158), (2789, 159), (2789, 49)),
# 	cell_location=(0, 0, 6, 6)
#
# 	cell_id=TableCell_1542010576467_3560,
# 	cell_coords=((2789, 49), (2789, 159), (3283, 166), (3284, 52)),
# 	cell_location=(0, 0, 7, 7)
#
# 	cell_id=TableCell_1542010570804_3472,
# 	cell_coords=((3284, 52), (3283, 166), (3472, 167), (3473, 51)),
# 	cell_location=(0, 0, 8, 8)
#
# 	cell_id=TableCell_1542010564112_3384,
# 	cell_coords=((3473, 51), (3472, 167), (3645, 168), (3644, 51)),
# 	cell_location=(0, 0, 9, 9)
#
# 	cell_id=TableCell_1542010556140_3296,
# 	cell_coords=((3644, 51), (3645, 168), (3813, 169), (3814, 51)),
# 	cell_location=(0, 0, 10, 10)
#
# 	cell_id=TableCell_1542010550976_3208,
# 	cell_coords=((3814, 51), (3813, 169), (4059, 170), (4060, 53)),
# 	cell_location=(0, 0, 11, 11)
#
# 	cell_id=TableCell_1542010541538_3120,
# 	cell_coords=((4060, 53), (4059, 170), (4649, 171), (4652, 61)),
# 	cell_location=(0, 0, 12, 12)
#
# 	cell_id=TableCell_1542010826379_4412,
# 	cell_coords=((39, 164), (41, 356), (226, 356), (225, 164)),
# 	cell_location=(1, 1, 0, 0)
#
# 	cell_id=TableCell_1542010826379_4410,
# 	cell_coords=((225, 164), (226, 356), (334, 356), (333, 164)),
# 	cell_location=(1, 1, 1, 1)
#
# 	cell_id=TableCell_1542010819733_4322,
# 	cell_coords=((333, 164), (334, 356), (1198, 356), (1195, 160)),
# 	cell_location=(1, 1, 2, 2)
#
# 	cell_id=TableCell_1542010811574_4234,
# 	cell_coords=((1195, 160), (1198, 356), (1708, 356), (1710, 159)),
# 	cell_location=(1, 1, 3, 3)
#
# 	cell_id=TableCell_1542010601084_3828,
# 	cell_coords=((1710, 159), (1708, 356), (2091, 357), (2094, 159)),
# 	cell_location=(1, 1, 4, 4)
#
# 	cell_id=TableCell_1542010592394_3740,
# 	cell_coords=((2094, 159), (2091, 357), (2331, 356), (2331, 158)),
# 	cell_location=(1, 1, 5, 5)
#
# 	cell_id=TableCell_1542010583456_3652,
# 	cell_coords=((2331, 158), (2331, 356), (2788, 356), (2789, 159)),
# 	cell_location=(1, 1, 6, 6)
#
# 	cell_id=TableCell_1542010576529_3564,
# 	cell_coords=((2789, 159), (2788, 356), (3280, 356), (3283, 166)),
# 	cell_location=(1, 1, 7, 7)
#
# 	cell_id=TableCell_1542010570851_3476,
# 	cell_coords=((3283, 166), (3280, 356), (3469, 356), (3472, 167)),
# 	cell_location=(1, 1, 8, 8)
#
# 	cell_id=TableCell_1542010564158_3388,
# 	cell_coords=((3472, 167), (3469, 356), (3643, 356), (3645, 168)),
# 	cell_location=(1, 1, 9, 9)
#
# 	cell_id=TableCell_1542010556171_3300,
# 	cell_coords=((3645, 168), (3643, 356), (3810, 357), (3813, 169)),
# 	cell_location=(1, 1, 10, 10)
#
# 	cell_id=TableCell_1542010551008_3212,
# 	cell_coords=((3813, 169), (3810, 357), (4056, 358), (4059, 170)),
# 	cell_location=(1, 1, 11, 11)
#
# 	cell_id=TableCell_1542010541570_3124,
# 	cell_coords=((4059, 170), (4056, 358), (4645, 359), (4649, 171)),
# 	cell_location=(1, 1, 12, 12)
#
# 	cell_id=TableCell_1542010826457_4416,
# 	cell_coords=((41, 356), (43, 536), (227, 536), (226, 356)),
# 	cell_location=(2, 2, 0, 0)
#
# 	cell_id=TableCell_1542010826457_4414,
# 	cell_coords=((226, 356), (227, 536), (335, 536), (334, 356)),
# 	cell_location=(2, 2, 1, 1)
#
# 	cell_id=TableCell_1542010819811_4326,
# 	cell_coords=((334, 356), (335, 536), (1198, 538), (1198, 356)),
# 	cell_location=(2, 2, 2, 2)
#
# 	cell_id=TableCell_1542010811652_4238,
# 	cell_coords=((1198, 356), (1198, 538), (1708, 539), (1708, 356)),
# 	cell_location=(2, 2, 3, 3)
#
# 	cell_id=TableCell_1542010601162_3832,
# 	cell_coords=((1708, 356), (1708, 539), (2094, 540), (2091, 357)),
# 	cell_location=(2, 2, 4, 4)
#
# 	cell_id=TableCell_1542010592457_3744,
# 	cell_coords=((2091, 357), (2094, 540), (2330, 541), (2331, 356)),
# 	cell_location=(2, 2, 5, 5)
#
# 	cell_id=TableCell_1542010583518_3656,
# 	cell_coords=((2331, 356), (2330, 541), (2787, 543), (2788, 356)),
# 	cell_location=(2, 2, 6, 6)
#
# 	cell_id=TableCell_1542010576576_3568,
# 	cell_coords=((2788, 356), (2787, 543), (3278, 545), (3280, 356)),
# 	cell_location=(2, 2, 7, 7)
#
# 	cell_id=TableCell_1542010570882_3480,
# 	cell_coords=((3280, 356), (3278, 545), (3467, 546), (3469, 356)),
# 	cell_location=(2, 2, 8, 8)
#
# 	cell_id=TableCell_1542010564205_3392,
# 	cell_coords=((3469, 356), (3467, 546), (3639, 547), (3643, 356)),
# 	cell_location=(2, 2, 9, 9)
#
# 	cell_id=TableCell_1542010556202_3304,
# 	cell_coords=((3643, 356), (3639, 547), (3808, 548), (3810, 357)),
# 	cell_location=(2, 2, 10, 10)
#
# 	cell_id=TableCell_1542010551039_3216,
# 	cell_coords=((3810, 357), (3808, 548), (4054, 549), (4056, 358)),
# 	cell_location=(2, 2, 11, 11)
#
# 	cell_id=TableCell_1542010541585_3128,
# 	cell_coords=((4056, 358), (4054, 549), (4640, 551), (4645, 359)),
# 	cell_location=(2, 2, 12, 12)
#
# 	cell_id=TableCell_1542010826550_4420,
# 	cell_coords=((43, 536), (45, 704), (228, 704), (227, 536)),
# 	cell_location=(3, 3, 0, 0)
#
# 	cell_id=TableCell_1542010826550_4418,
# 	cell_coords=((227, 536), (228, 704), (336, 705), (335, 536)),
# 	cell_location=(3, 3, 1, 1)
#
# 	cell_id=TableCell_1542010819889_4330,
# 	cell_coords=((335, 536), (336, 705), (1198, 708), (1198, 538)),
# 	cell_location=(3, 3, 2, 2)
#
# 	cell_id=TableCell_1542010811730_4242,
# 	cell_coords=((1198, 538), (1198, 708), (1707, 710), (1708, 539)),
# 	cell_location=(3, 3, 3, 3)
#
# 	cell_id=TableCell_1542010601224_3836,
# 	cell_coords=((1708, 539), (1707, 710), (2093, 712), (2094, 540)),
# 	cell_location=(3, 3, 4, 4)
#
# 	cell_id=TableCell_1542010592519_3748,
# 	cell_coords=((2094, 540), (2093, 712), (2330, 714), (2330, 541)),
# 	cell_location=(3, 3, 5, 5)
#
# 	cell_id=TableCell_1542010583565_3660,
# 	cell_coords=((2330, 541), (2330, 714), (2786, 716), (2787, 543)),
# 	cell_location=(3, 3, 6, 6)
#
# 	cell_id=TableCell_1542010576623_3572,
# 	cell_coords=((2787, 543), (2786, 716), (3276, 719), (3278, 545)),
# 	cell_location=(3, 3, 7, 7)
#
# 	cell_id=TableCell_1542010570929_3484,
# 	cell_coords=((3278, 545), (3276, 719), (3465, 720), (3467, 546)),
# 	cell_location=(3, 3, 8, 8)
#
# 	cell_id=TableCell_1542010564236_3396,
# 	cell_coords=((3467, 546), (3465, 720), (3637, 721), (3639, 547)),
# 	cell_location=(3, 3, 9, 9)
#
# 	cell_id=TableCell_1542010556234_3308,
# 	cell_coords=((3639, 547), (3637, 721), (3806, 722), (3808, 548)),
# 	cell_location=(3, 3, 10, 10)
#
# 	cell_id=TableCell_1542010551070_3220,
# 	cell_coords=((3808, 548), (3806, 722), (4051, 724), (4054, 549)),
# 	cell_location=(3, 3, 11, 11)
#
# 	cell_id=TableCell_1542010541616_3132,
# 	cell_coords=((4054, 549), (4051, 724), (4636, 727), (4640, 551)),
# 	cell_location=(3, 3, 12, 12)
#
# 	cell_id=TableCell_1542010826628_4424,
# 	cell_coords=((45, 704), (47, 863), (232, 863), (228, 704)),
# 	cell_location=(4, 4, 0, 0)
#
# 	cell_id=TableCell_1542010826628_4422,
# 	cell_coords=((228, 704), (232, 863), (340, 864), (336, 705)),
# 	cell_location=(4, 4, 1, 1)
#
# 	cell_id=TableCell_1542010819967_4334,
# 	cell_coords=((336, 705), (340, 864), (1198, 869), (1198, 708)),
# 	cell_location=(4, 4, 2, 2)
#
# 	cell_id=TableCell_1542010811793_4246,
# 	cell_coords=((1198, 708), (1198, 869), (1707, 873), (1707, 710)),
# 	cell_location=(4, 4, 3, 3)
#
# 	cell_id=TableCell_1542010601302_3840,
# 	cell_coords=((1707, 710), (1707, 873), (2091, 874), (2093, 712)),
# 	cell_location=(4, 4, 4, 4)
#
# 	cell_id=TableCell_1542010592566_3752,
# 	cell_coords=((2093, 712), (2091, 874), (2330, 878), (2330, 714)),
# 	cell_location=(4, 4, 5, 5)
#
# 	cell_id=TableCell_1542010583627_3664,
# 	cell_coords=((2330, 714), (2330, 878), (2785, 882), (2786, 716)),
# 	cell_location=(4, 4, 6, 6)
#
# 	cell_id=TableCell_1542010576670_3576,
# 	cell_coords=((2786, 716), (2785, 882), (3275, 886), (3276, 719)),
# 	cell_location=(4, 4, 7, 7)
#
# 	cell_id=TableCell_1542010570976_3488,
# 	cell_coords=((3276, 719), (3275, 886), (3463, 888), (3465, 720)),
# 	cell_location=(4, 4, 8, 8)
#
# 	cell_id=TableCell_1542010564268_3400,
# 	cell_coords=((3465, 720), (3463, 888), (3631, 890), (3637, 721)),
# 	cell_location=(4, 4, 9, 9)
#
# 	cell_id=TableCell_1542010556265_3312,
# 	cell_coords=((3637, 721), (3631, 890), (3803, 894), (3806, 722)),
# 	cell_location=(4, 4, 10, 10)
#
# 	cell_id=TableCell_1542010551086_3224,
# 	cell_coords=((3806, 722), (3803, 894), (4048, 896), (4051, 724)),
# 	cell_location=(4, 4, 11, 11)
#
# 	cell_id=TableCell_1542010541632_3136,
# 	cell_coords=((4051, 724), (4048, 896), (4632, 899), (4636, 727)),
# 	cell_location=(4, 4, 12, 12)
#
# 	cell_id=TableCell_1542010826706_4428,
# 	cell_coords=((47, 863), (49, 1052), (233, 1052), (232, 863)),
# 	cell_location=(5, 5, 0, 0)
#
# 	cell_id=TableCell_1542010826706_4426,
# 	cell_coords=((232, 863), (233, 1052), (341, 1052), (340, 864)),
# 	cell_location=(5, 5, 1, 1)
#
# 	cell_id=TableCell_1542010820045_4338,
# 	cell_coords=((340, 864), (341, 1052), (1198, 1054), (1198, 869)),
# 	cell_location=(5, 5, 2, 2)
#
# 	cell_id=TableCell_1542010811871_4250,
# 	cell_coords=((1198, 869), (1198, 1054), (1706, 1055), (1707, 873)),
# 	cell_location=(5, 5, 3, 3)
#
# 	cell_id=TableCell_1542010601364_3844,
# 	cell_coords=((1707, 873), (1706, 1055), (2090, 1054), (2091, 874)),
# 	cell_location=(5, 5, 4, 4)
#
# 	cell_id=TableCell_1542010592628_3756,
# 	cell_coords=((2091, 874), (2090, 1054), (2329, 1057), (2330, 878)),
# 	cell_location=(5, 5, 5, 5)
#
# 	cell_id=TableCell_1542010583674_3668,
# 	cell_coords=((2330, 878), (2329, 1057), (2784, 1059), (2785, 882)),
# 	cell_location=(5, 5, 6, 6)
#
# 	cell_id=TableCell_1542010576716_3580,
# 	cell_coords=((2785, 882), (2784, 1059), (3273, 1061), (3275, 886)),
# 	cell_location=(5, 5, 7, 7)
#
# 	cell_id=TableCell_1542010571022_3492,
# 	cell_coords=((3275, 886), (3273, 1061), (3461, 1062), (3463, 888)),
# 	cell_location=(5, 5, 8, 8)
#
# 	cell_id=TableCell_1542010564314_3404,
# 	cell_coords=((3463, 888), (3461, 1062), (3629, 1063), (3631, 890)),
# 	cell_location=(5, 5, 9, 9)
#
# 	cell_id=TableCell_1542010556296_3316,
# 	cell_coords=((3631, 890), (3629, 1063), (3801, 1066), (3803, 894)),
# 	cell_location=(5, 5, 10, 10)
#
# 	cell_id=TableCell_1542010551117_3228,
# 	cell_coords=((3803, 894), (3801, 1066), (4046, 1067), (4048, 896)),
# 	cell_location=(5, 5, 11, 11)
#
# 	cell_id=TableCell_1542010541663_3140,
# 	cell_coords=((4048, 896), (4046, 1067), (4628, 1067), (4632, 899)),
# 	cell_location=(5, 5, 12, 12)
#
# 	cell_id=TableCell_1542010826800_4432,
# 	cell_coords=((49, 1052), (51, 1219), (233, 1217), (233, 1052)),
# 	cell_location=(6, 6, 0, 0)
#
# 	cell_id=TableCell_1542010826800_4430,
# 	cell_coords=((233, 1052), (233, 1217), (340, 1217), (341, 1052)),
# 	cell_location=(6, 6, 1, 1)
#
# 	cell_id=TableCell_1542010820123_4342,
# 	cell_coords=((341, 1052), (340, 1217), (1198, 1220), (1198, 1054)),
# 	cell_location=(6, 6, 2, 2)
#
# 	cell_id=TableCell_1542010811933_4254,
# 	cell_coords=((1198, 1054), (1198, 1220), (1706, 1221), (1706, 1055)),
# 	cell_location=(6, 6, 3, 3)
#
# 	cell_id=TableCell_1542010601427_3848,
# 	cell_coords=((1706, 1055), (1706, 1221), (2088, 1220), (2090, 1054)),
# 	cell_location=(6, 6, 4, 4)
#
# 	cell_id=TableCell_1542010592691_3760,
# 	cell_coords=((2090, 1054), (2088, 1220), (2329, 1223), (2329, 1057)),
# 	cell_location=(6, 6, 5, 5)
#
# 	cell_id=TableCell_1542010583736_3672,
# 	cell_coords=((2329, 1057), (2329, 1223), (2783, 1224), (2784, 1059)),
# 	cell_location=(6, 6, 6, 6)
#
# 	cell_id=TableCell_1542010576763_3584,
# 	cell_coords=((2784, 1059), (2783, 1224), (3271, 1225), (3273, 1061)),
# 	cell_location=(6, 6, 7, 7)
#
# 	cell_id=TableCell_1542010571054_3496,
# 	cell_coords=((3273, 1061), (3271, 1225), (3459, 1226), (3461, 1062)),
# 	cell_location=(6, 6, 8, 8)
#
# 	cell_id=TableCell_1542010564346_3408,
# 	cell_coords=((3461, 1062), (3459, 1226), (3627, 1227), (3629, 1063)),
# 	cell_location=(6, 6, 9, 9)
#
# 	cell_id=TableCell_1542010556327_3320,
# 	cell_coords=((3629, 1063), (3627, 1227), (3794, 1228), (3801, 1066)),
# 	cell_location=(6, 6, 10, 10)
#
# 	cell_id=TableCell_1542010551148_3232,
# 	cell_coords=((3801, 1066), (3794, 1228), (4039, 1229), (4046, 1067)),
# 	cell_location=(6, 6, 11, 11)
#
# 	cell_id=TableCell_1542010541679_3144,
# 	cell_coords=((4046, 1067), (4039, 1229), (4624, 1231), (4628, 1067)),
# 	cell_location=(6, 6, 12, 12)
#
# 	cell_id=TableCell_1542010826862_4436,
# 	cell_coords=((51, 1219), (53, 1379), (234, 1377), (233, 1217)),
# 	cell_location=(7, 7, 0, 0)
#
# 	cell_id=TableCell_1542010826862_4434,
# 	cell_coords=((233, 1217), (234, 1377), (341, 1377), (340, 1217)),
# 	cell_location=(7, 7, 1, 1)
#
# 	cell_id=TableCell_1542010820186_4346,
# 	cell_coords=((340, 1217), (341, 1377), (1198, 1382), (1198, 1220)),
# 	cell_location=(7, 7, 2, 2)
#
# 	cell_id=TableCell_1542010811996_4258,
# 	cell_coords=((1198, 1220), (1198, 1382), (1705, 1384), (1706, 1221)),
# 	cell_location=(7, 7, 3, 3)
#
# 	cell_id=TableCell_1542010601489_3852,
# 	cell_coords=((1706, 1221), (1705, 1384), (2088, 1384), (2088, 1220)),
# 	cell_location=(7, 7, 4, 4)
#
# 	cell_id=TableCell_1542010592738_3764,
# 	cell_coords=((2088, 1220), (2088, 1384), (2329, 1387), (2329, 1223)),
# 	cell_location=(7, 7, 5, 5)
#
# 	cell_id=TableCell_1542010583783_3676,
# 	cell_coords=((2329, 1223), (2329, 1387), (2782, 1389), (2783, 1224)),
# 	cell_location=(7, 7, 6, 6)
#
# 	cell_id=TableCell_1542010576810_3588,
# 	cell_coords=((2783, 1224), (2782, 1389), (3269, 1391), (3271, 1225)),
# 	cell_location=(7, 7, 7, 7)
#
# 	cell_id=TableCell_1542010571100_3500,
# 	cell_coords=((3271, 1225), (3269, 1391), (3457, 1392), (3459, 1226)),
# 	cell_location=(7, 7, 8, 8)
#
# 	cell_id=TableCell_1542010564377_3412,
# 	cell_coords=((3459, 1226), (3457, 1392), (3626, 1393), (3627, 1227)),
# 	cell_location=(7, 7, 9, 9)
#
# 	cell_id=TableCell_1542010556358_3324,
# 	cell_coords=((3627, 1227), (3626, 1393), (3792, 1394), (3794, 1228)),
# 	cell_location=(7, 7, 10, 10)
#
# 	cell_id=TableCell_1542010551164_3236,
# 	cell_coords=((3794, 1228), (3792, 1394), (4036, 1396), (4039, 1229)),
# 	cell_location=(7, 7, 11, 11)
#
# 	cell_id=TableCell_1542010541710_3148,
# 	cell_coords=((4039, 1229), (4036, 1396), (4620, 1399), (4624, 1231)),
# 	cell_location=(7, 7, 12, 12)
#
# 	cell_id=TableCell_1542010826940_4440,
# 	cell_coords=((53, 1379), (55, 1542), (239, 1539), (234, 1377)),
# 	cell_location=(8, 8, 0, 0)
#
# 	cell_id=TableCell_1542010826940_4438,
# 	cell_coords=((234, 1377), (239, 1539), (346, 1539), (341, 1377)),
# 	cell_location=(8, 8, 1, 1)
#
# 	cell_id=TableCell_1542010820264_4350,
# 	cell_coords=((341, 1377), (346, 1539), (1198, 1539), (1198, 1382)),
# 	cell_location=(8, 8, 2, 2)
#
# 	cell_id=TableCell_1542010812058_4262,
# 	cell_coords=((1198, 1382), (1198, 1539), (1705, 1539), (1705, 1384)),
# 	cell_location=(8, 8, 3, 3)
#
# 	cell_id=TableCell_1542010601536_3856,
# 	cell_coords=((1705, 1384), (1705, 1539), (2087, 1539), (2088, 1384)),
# 	cell_location=(8, 8, 4, 4)
#
# 	cell_id=TableCell_1542010592800_3768,
# 	cell_coords=((2088, 1384), (2087, 1539), (2328, 1539), (2329, 1387)),
# 	cell_location=(8, 8, 5, 5)
#
# 	cell_id=TableCell_1542010583830_3680,
# 	cell_coords=((2329, 1387), (2328, 1539), (2781, 1539), (2782, 1389)),
# 	cell_location=(8, 8, 6, 6)
#
# 	cell_id=TableCell_1542010576857_3592,
# 	cell_coords=((2782, 1389), (2781, 1539), (3267, 1539), (3269, 1391)),
# 	cell_location=(8, 8, 7, 7)
#
# 	cell_id=TableCell_1542010571132_3504,
# 	cell_coords=((3269, 1391), (3267, 1539), (3455, 1539), (3457, 1392)),
# 	cell_location=(8, 8, 8, 8)
#
# 	cell_id=TableCell_1542010564408_3416,
# 	cell_coords=((3457, 1392), (3455, 1539), (3624, 1539), (3626, 1393)),
# 	cell_location=(8, 8, 9, 9)
#
# 	cell_id=TableCell_1542010556374_3328,
# 	cell_coords=((3626, 1393), (3624, 1539), (3790, 1539), (3792, 1394)),
# 	cell_location=(8, 8, 10, 10)
#
# 	cell_id=TableCell_1542010551195_3240,
# 	cell_coords=((3792, 1394), (3790, 1539), (4034, 1539), (4036, 1396)),
# 	cell_location=(8, 8, 11, 11)
#
# 	cell_id=TableCell_1542010541726_3152,
# 	cell_coords=((4036, 1396), (4034, 1539), (4617, 1539), (4620, 1399)),
# 	cell_location=(8, 8, 12, 12)
#
# 	cell_id=TableCell_1542010827018_4444,
# 	cell_coords=((55, 1542), (57, 1739), (240, 1738), (239, 1539)),
# 	cell_location=(9, 9, 0, 0)
#
# 	cell_id=TableCell_1542010827018_4442,
# 	cell_coords=((239, 1539), (240, 1738), (347, 1739), (346, 1539)),
# 	cell_location=(9, 9, 1, 1)
#
# 	cell_id=TableCell_1542010820326_4354,
# 	cell_coords=((346, 1539), (347, 1739), (1198, 1750), (1198, 1539)),
# 	cell_location=(9, 9, 2, 2)
#
# 	cell_id=TableCell_1542010812120_4266,
# 	cell_coords=((1198, 1539), (1198, 1750), (1704, 1756), (1705, 1539)),
# 	cell_location=(9, 9, 3, 3)
#
# 	cell_id=TableCell_1542010601598_3860,
# 	cell_coords=((1705, 1539), (1704, 1756), (2086, 1760), (2087, 1539)),
# 	cell_location=(9, 9, 4, 4)
#
# 	cell_id=TableCell_1542010592847_3772,
# 	cell_coords=((2087, 1539), (2086, 1760), (2328, 1763), (2328, 1539)),
# 	cell_location=(9, 9, 5, 5)
#
# 	cell_id=TableCell_1542010583877_3684,
# 	cell_coords=((2328, 1539), (2328, 1763), (2780, 1768), (2781, 1539)),
# 	cell_location=(9, 9, 6, 6)
#
# 	cell_id=TableCell_1542010576904_3596,
# 	cell_coords=((2781, 1539), (2780, 1768), (3265, 1774), (3267, 1539)),
# 	cell_location=(9, 9, 7, 7)
#
# 	cell_id=TableCell_1542010571163_3508,
# 	cell_coords=((3267, 1539), (3265, 1774), (3452, 1777), (3455, 1539)),
# 	cell_location=(9, 9, 8, 8)
#
# 	cell_id=TableCell_1542010564439_3420,
# 	cell_coords=((3455, 1539), (3452, 1777), (3622, 1779), (3624, 1539)),
# 	cell_location=(9, 9, 9, 9)
#
# 	cell_id=TableCell_1542010556405_3332,
# 	cell_coords=((3624, 1539), (3622, 1779), (3787, 1781), (3790, 1539)),
# 	cell_location=(9, 9, 10, 10)
#
# 	cell_id=TableCell_1542010551210_3244,
# 	cell_coords=((3790, 1539), (3787, 1781), (4031, 1784), (4034, 1539)),
# 	cell_location=(9, 9, 11, 11)
#
# 	cell_id=TableCell_1542010541741_3156,
# 	cell_coords=((4034, 1539), (4031, 1784), (4612, 1791), (4617, 1539)),
# 	cell_location=(9, 9, 12, 12)
#
# 	cell_id=TableCell_1542010827081_4448,
# 	cell_coords=((57, 1739), (63, 1850), (239, 1851), (240, 1738)),
# 	cell_location=(10, 10, 0, 0)
#
# 	cell_id=TableCell_1542010827081_4446,
# 	cell_coords=((240, 1738), (239, 1851), (353, 1852), (347, 1739)),
# 	cell_location=(10, 10, 1, 1)
#
# 	cell_id=TableCell_1542010820388_4358,
# 	cell_coords=((347, 1739), (353, 1852), (1201, 1861), (1198, 1750)),
# 	cell_location=(10, 10, 2, 2)
#
# 	cell_id=TableCell_1542010812183_4270,
# 	cell_coords=((1198, 1750), (1201, 1861), (1703, 1867), (1704, 1756)),
# 	cell_location=(10, 10, 3, 3)
#
# 	cell_id=TableCell_1542010601645_3864,
# 	cell_coords=((1704, 1756), (1703, 1867), (2082, 1871), (2086, 1760)),
# 	cell_location=(10, 10, 4, 4)
#
# 	cell_id=TableCell_1542010592894_3776,
# 	cell_coords=((2086, 1760), (2082, 1871), (2328, 1874), (2328, 1763)),
# 	cell_location=(10, 10, 5, 5)
#
# 	cell_id=TableCell_1542010583924_3688,
# 	cell_coords=((2328, 1763), (2328, 1874), (2779, 1879), (2780, 1768)),
# 	cell_location=(10, 10, 6, 6)
#
# 	cell_id=TableCell_1542010576935_3600,
# 	cell_coords=((2780, 1768), (2779, 1879), (3264, 1885), (3265, 1774)),
# 	cell_location=(10, 10, 7, 7)
#
# 	cell_id=TableCell_1542010571210_3512,
# 	cell_coords=((3265, 1774), (3264, 1885), (3451, 1888), (3452, 1777)),
# 	cell_location=(10, 10, 8, 8)
#
# 	cell_id=TableCell_1542010564470_3424,
# 	cell_coords=((3452, 1777), (3451, 1888), (3620, 1890), (3622, 1779)),
# 	cell_location=(10, 10, 9, 9)
#
# 	cell_id=TableCell_1542010556436_3336,
# 	cell_coords=((3622, 1779), (3620, 1890), (3786, 1892), (3787, 1781)),
# 	cell_location=(10, 10, 10, 10)
#
# 	cell_id=TableCell_1542010551242_3248,
# 	cell_coords=((3787, 1781), (3786, 1892), (4030, 1895), (4031, 1784)),
# 	cell_location=(10, 10, 11, 11)
#
# 	cell_id=TableCell_1542010541772_3160,
# 	cell_coords=((4031, 1784), (4030, 1895), (4609, 1902), (4612, 1791)),
# 	cell_location=(10, 10, 12, 12)
#
# 	cell_id=TableCell_1542010827143_4452,
# 	cell_coords=((63, 1850), (64, 1981), (240, 1983), (239, 1851)),
# 	cell_location=(11, 11, 0, 0)
#
# 	cell_id=TableCell_1542010827143_4450,
# 	cell_coords=((239, 1851), (240, 1983), (353, 1985), (353, 1852)),
# 	cell_location=(11, 11, 1, 1)
#
# 	cell_id=TableCell_1542010820451_4362,
# 	cell_coords=((353, 1852), (353, 1985), (1201, 1998), (1201, 1861)),
# 	cell_location=(11, 11, 2, 2)
#
# 	cell_id=TableCell_1542010812245_4274,
# 	cell_coords=((1201, 1861), (1201, 1998), (1703, 2006), (1703, 1867)),
# 	cell_location=(11, 11, 3, 3)
#
# 	cell_id=TableCell_1542010601692_3868,
# 	cell_coords=((1703, 1867), (1703, 2006), (2081, 2012), (2082, 1871)),
# 	cell_location=(11, 11, 4, 4)
#
# 	cell_id=TableCell_1542010592940_3780,
# 	cell_coords=((2082, 1871), (2081, 2012), (2327, 2016), (2328, 1874)),
# 	cell_location=(11, 11, 5, 5)
#
# 	cell_id=TableCell_1542010583970_3692,
# 	cell_coords=((2328, 1874), (2327, 2016), (2779, 2024), (2779, 1879)),
# 	cell_location=(11, 11, 6, 6)
#
# 	cell_id=TableCell_1542010576982_3604,
# 	cell_coords=((2779, 1879), (2779, 2024), (3262, 2032), (3264, 1885)),
# 	cell_location=(11, 11, 7, 7)
#
# 	cell_id=TableCell_1542010571241_3516,
# 	cell_coords=((3264, 1885), (3262, 2032), (3449, 2036), (3451, 1888)),
# 	cell_location=(11, 11, 8, 8)
#
# 	cell_id=TableCell_1542010564517_3428,
# 	cell_coords=((3451, 1888), (3449, 2036), (3619, 2039), (3620, 1890)),
# 	cell_location=(11, 11, 9, 9)
#
# 	cell_id=TableCell_1542010556468_3340,
# 	cell_coords=((3620, 1890), (3619, 2039), (3784, 2042), (3786, 1892)),
# 	cell_location=(11, 11, 10, 10)
#
# 	cell_id=TableCell_1542010551257_3252,
# 	cell_coords=((3786, 1892), (3784, 2042), (4028, 2047), (4030, 1895)),
# 	cell_location=(11, 11, 11, 11)
#
# 	cell_id=TableCell_1542010541788_3164,
# 	cell_coords=((4030, 1895), (4028, 2047), (4606, 2057), (4609, 1902)),
# 	cell_location=(11, 11, 12, 12)
#
# 	cell_id=TableCell_1542010827206_4456,
# 	cell_coords=((64, 1981), (66, 2175), (241, 2175), (240, 1983)),
# 	cell_location=(12, 12, 0, 0)
#
# 	cell_id=TableCell_1542010827206_4454,
# 	cell_coords=((240, 1983), (241, 2175), (354, 2173), (353, 1985)),
# 	cell_location=(12, 12, 1, 1)
#
# 	cell_id=TableCell_1542010820513_4366,
# 	cell_coords=((353, 1985), (354, 2173), (1200, 2179), (1201, 1998)),
# 	cell_location=(12, 12, 2, 2)
#
# 	cell_id=TableCell_1542010812308_4278,
# 	cell_coords=((1201, 1998), (1200, 2179), (1702, 2183), (1703, 2006)),
# 	cell_location=(12, 12, 3, 3)
#
# 	cell_id=TableCell_1542010601754_3872,
# 	cell_coords=((1703, 2006), (1702, 2183), (2084, 2186), (2081, 2012)),
# 	cell_location=(12, 12, 4, 4)
#
# 	cell_id=TableCell_1542010592987_3784,
# 	cell_coords=((2081, 2012), (2084, 2186), (2327, 2188), (2327, 2016)),
# 	cell_location=(12, 12, 5, 5)
#
# 	cell_id=TableCell_1542010584017_3696,
# 	cell_coords=((2327, 2016), (2327, 2188), (2778, 2192), (2779, 2024)),
# 	cell_location=(12, 12, 6, 6)
#
# 	cell_id=TableCell_1542010577013_3608,
# 	cell_coords=((2779, 2024), (2778, 2192), (3265, 2196), (3262, 2032)),
# 	cell_location=(12, 12, 7, 7)
#
# 	cell_id=TableCell_1542010571272_3520,
# 	cell_coords=((3262, 2032), (3265, 2196), (3450, 2198), (3449, 2036)),
# 	cell_location=(12, 12, 8, 8)
#
# 	cell_id=TableCell_1542010564548_3432,
# 	cell_coords=((3449, 2036), (3450, 2198), (3620, 2200), (3619, 2039)),
# 	cell_location=(12, 12, 9, 9)
#
# 	cell_id=TableCell_1542010556499_3344,
# 	cell_coords=((3619, 2039), (3620, 2200), (3785, 2202), (3784, 2042)),
# 	cell_location=(12, 12, 10, 10)
#
# 	cell_id=TableCell_1542010551288_3256,
# 	cell_coords=((3784, 2042), (3785, 2202), (4026, 2204), (4028, 2047)),
# 	cell_location=(12, 12, 11, 11)
#
# 	cell_id=TableCell_1542010541804_3168,
# 	cell_coords=((4028, 2047), (4026, 2204), (4603, 2209), (4606, 2057)),
# 	cell_location=(12, 12, 12, 12)
#
# 	cell_id=TableCell_1542010827268_4460,
# 	cell_coords=((66, 2175), (69, 2388), (243, 2388), (241, 2175)),
# 	cell_location=(13, 13, 0, 0)
#
# 	cell_id=TableCell_1542010827268_4458,
# 	cell_coords=((241, 2175), (243, 2388), (355, 2386), (354, 2173)),
# 	cell_location=(13, 13, 1, 1)
#
# 	cell_id=TableCell_1542010820560_4370,
# 	cell_coords=((354, 2173), (355, 2386), (1200, 2391), (1200, 2179)),
# 	cell_location=(13, 13, 2, 2)
#
# 	cell_id=TableCell_1542010812354_4282,
# 	cell_coords=((1200, 2179), (1200, 2391), (1702, 2394), (1702, 2183)),
# 	cell_location=(13, 13, 3, 3)
#
# 	cell_id=TableCell_1542010601801_3876,
# 	cell_coords=((1702, 2183), (1702, 2394), (2083, 2397), (2084, 2186)),
# 	cell_location=(13, 13, 4, 4)
#
# 	cell_id=TableCell_1542010593034_3788,
# 	cell_coords=((2084, 2186), (2083, 2397), (2326, 2399), (2327, 2188)),
# 	cell_location=(13, 13, 5, 5)
#
# 	cell_id=TableCell_1542010584048_3700,
# 	cell_coords=((2327, 2188), (2326, 2399), (2777, 2402), (2778, 2192)),
# 	cell_location=(13, 13, 6, 6)
#
# 	cell_id=TableCell_1542010577060_3612,
# 	cell_coords=((2778, 2192), (2777, 2402), (3263, 2405), (3265, 2196)),
# 	cell_location=(13, 13, 7, 7)
#
# 	cell_id=TableCell_1542010571303_3524,
# 	cell_coords=((3265, 2196), (3263, 2405), (3448, 2407), (3450, 2198)),
# 	cell_location=(13, 13, 8, 8)
#
# 	cell_id=TableCell_1542010564580_3436,
# 	cell_coords=((3450, 2198), (3448, 2407), (3618, 2409), (3620, 2200)),
# 	cell_location=(13, 13, 9, 9)
#
# 	cell_id=TableCell_1542010556530_3348,
# 	cell_coords=((3620, 2200), (3618, 2409), (3783, 2411), (3785, 2202)),
# 	cell_location=(13, 13, 10, 10)
#
# 	cell_id=TableCell_1542010551304_3260,
# 	cell_coords=((3785, 2202), (3783, 2411), (4023, 2413), (4026, 2204)),
# 	cell_location=(13, 13, 11, 11)
#
# 	cell_id=TableCell_1542010541835_3172,
# 	cell_coords=((4026, 2204), (4023, 2413), (4599, 2417), (4603, 2209)),
# 	cell_location=(13, 13, 12, 12)
#
# 	cell_id=TableCell_1542010827330_4464,
# 	cell_coords=((69, 2388), (69, 2541), (243, 2541), (243, 2388)),
# 	cell_location=(14, 14, 0, 0)
#
# 	cell_id=TableCell_1542010827330_4462,
# 	cell_coords=((243, 2388), (243, 2541), (354, 2541), (355, 2386)),
# 	cell_location=(14, 14, 1, 1)
#
# 	cell_id=TableCell_1542010820622_4374,
# 	cell_coords=((355, 2386), (354, 2541), (1200, 2545), (1200, 2391)),
# 	cell_location=(14, 14, 2, 2)
#
# 	cell_id=TableCell_1542010812401_4286,
# 	cell_coords=((1200, 2391), (1200, 2545), (1703, 2547), (1702, 2394)),
# 	cell_location=(14, 14, 3, 3)
#
# 	cell_id=TableCell_1542010601848_3880,
# 	cell_coords=((1702, 2394), (1703, 2547), (2083, 2549), (2083, 2397)),
# 	cell_location=(14, 14, 4, 4)
#
# 	cell_id=TableCell_1542010593081_3792,
# 	cell_coords=((2083, 2397), (2083, 2549), (2326, 2551), (2326, 2399)),
# 	cell_location=(14, 14, 5, 5)
#
# 	cell_id=TableCell_1542010584095_3704,
# 	cell_coords=((2326, 2399), (2326, 2551), (2776, 2553), (2777, 2402)),
# 	cell_location=(14, 14, 6, 6)
#
# 	cell_id=TableCell_1542010577091_3616,
# 	cell_coords=((2777, 2402), (2776, 2553), (3265, 2558), (3263, 2405)),
# 	cell_location=(14, 14, 7, 7)
#
# 	cell_id=TableCell_1542010571334_3528,
# 	cell_coords=((3263, 2405), (3265, 2558), (3446, 2559), (3448, 2407)),
# 	cell_location=(14, 14, 8, 8)
#
# 	cell_id=TableCell_1542010564595_3440,
# 	cell_coords=((3448, 2407), (3446, 2559), (3615, 2560), (3618, 2409)),
# 	cell_location=(14, 14, 9, 9)
#
# 	cell_id=TableCell_1542010556546_3352,
# 	cell_coords=((3618, 2409), (3615, 2560), (3780, 2561), (3783, 2411)),
# 	cell_location=(14, 14, 10, 10)
#
# 	cell_id=TableCell_1542010551335_3264,
# 	cell_coords=((3783, 2411), (3780, 2561), (4021, 2561), (4023, 2413)),
# 	cell_location=(14, 14, 11, 11)
#
# 	cell_id=TableCell_1542010541850_3176,
# 	cell_coords=((4023, 2413), (4021, 2561), (4596, 2565), (4599, 2417)),
# 	cell_location=(14, 14, 12, 12)
#
# 	cell_id=TableCell_1542010827377_4468,
# 	cell_coords=((69, 2541), (71, 2717), (244, 2717), (243, 2541)),
# 	cell_location=(15, 15, 0, 0)
#
# 	cell_id=TableCell_1542010827377_4466,
# 	cell_coords=((243, 2541), (244, 2717), (355, 2718), (354, 2541)),
# 	cell_location=(15, 15, 1, 1)
#
# 	cell_id=TableCell_1542010820685_4378,
# 	cell_coords=((354, 2541), (355, 2718), (1200, 2722), (1200, 2545)),
# 	cell_location=(15, 15, 2, 2)
#
# 	cell_id=TableCell_1542010812464_4290,
# 	cell_coords=((1200, 2545), (1200, 2722), (1703, 2725), (1703, 2547)),
# 	cell_location=(15, 15, 3, 3)
#
# 	cell_id=TableCell_1542010601895_3884,
# 	cell_coords=((1703, 2547), (1703, 2725), (2082, 2728), (2083, 2549)),
# 	cell_location=(15, 15, 4, 4)
#
# 	cell_id=TableCell_1542010593128_3796,
# 	cell_coords=((2083, 2549), (2082, 2728), (2326, 2730), (2326, 2551)),
# 	cell_location=(15, 15, 5, 5)
#
# 	cell_id=TableCell_1542010584126_3708,
# 	cell_coords=((2326, 2551), (2326, 2730), (2775, 2733), (2776, 2553)),
# 	cell_location=(15, 15, 6, 6)
#
# 	cell_id=TableCell_1542010577122_3620,
# 	cell_coords=((2776, 2553), (2775, 2733), (3263, 2738), (3265, 2558)),
# 	cell_location=(15, 15, 7, 7)
#
# 	cell_id=TableCell_1542010571381_3532,
# 	cell_coords=((3265, 2558), (3263, 2738), (3444, 2740), (3446, 2559)),
# 	cell_location=(15, 15, 8, 8)
#
# 	cell_id=TableCell_1542010564626_3444,
# 	cell_coords=((3446, 2559), (3444, 2740), (3613, 2742), (3615, 2560)),
# 	cell_location=(15, 15, 9, 9)
#
# 	cell_id=TableCell_1542010556577_3356,
# 	cell_coords=((3615, 2560), (3613, 2742), (3778, 2744), (3780, 2561)),
# 	cell_location=(15, 15, 10, 10)
#
# 	cell_id=TableCell_1542010551351_3268,
# 	cell_coords=((3780, 2561), (3778, 2744), (4018, 2744), (4021, 2561)),
# 	cell_location=(15, 15, 11, 11)
#
# 	cell_id=TableCell_1542010541866_3180,
# 	cell_coords=((4021, 2561), (4018, 2744), (4592, 2749), (4596, 2565)),
# 	cell_location=(15, 15, 12, 12)
#
# 	cell_id=TableCell_1542010827440_4472,
# 	cell_coords=((71, 2717), (70, 2885), (246, 2887), (244, 2717)),
# 	cell_location=(16, 16, 0, 0)
#
# 	cell_id=TableCell_1542010827440_4470,
# 	cell_coords=((244, 2717), (246, 2887), (355, 2888), (355, 2718)),
# 	cell_location=(16, 16, 1, 1)
#
# 	cell_id=TableCell_1542010820732_4382,
# 	cell_coords=((355, 2718), (355, 2888), (1203, 2888), (1200, 2722)),
# 	cell_location=(16, 16, 2, 2)
#
# 	cell_id=TableCell_1542010812510_4294,
# 	cell_coords=((1200, 2722), (1203, 2888), (1706, 2885), (1703, 2725)),
# 	cell_location=(16, 16, 3, 3)
#
# 	cell_id=TableCell_1542010601942_3888,
# 	cell_coords=((1703, 2725), (1706, 2885), (2083, 2885), (2082, 2728)),
# 	cell_location=(16, 16, 4, 4)
#
# 	cell_id=TableCell_1542010593174_3800,
# 	cell_coords=((2082, 2728), (2083, 2885), (2329, 2888), (2326, 2730)),
# 	cell_location=(16, 16, 5, 5)
#
# 	cell_id=TableCell_1542010584173_3712,
# 	cell_coords=((2326, 2730), (2329, 2888), (2774, 2886), (2775, 2733)),
# 	cell_location=(16, 16, 6, 6)
#
# 	cell_id=TableCell_1542010577153_3624,
# 	cell_coords=((2775, 2733), (2774, 2886), (3258, 2887), (3263, 2738)),
# 	cell_location=(16, 16, 7, 7)
#
# 	cell_id=TableCell_1542010571397_3536,
# 	cell_coords=((3263, 2738), (3258, 2887), (3444, 2888), (3444, 2740)),
# 	cell_location=(16, 16, 8, 8)
#
# 	cell_id=TableCell_1542010564658_3448,
# 	cell_coords=((3444, 2740), (3444, 2888), (3610, 2889), (3613, 2742)),
# 	cell_location=(16, 16, 9, 9)
#
# 	cell_id=TableCell_1542010556592_3360,
# 	cell_coords=((3613, 2742), (3610, 2889), (3774, 2890), (3778, 2744)),
# 	cell_location=(16, 16, 10, 10)
#
# 	cell_id=TableCell_1542010551366_3272,
# 	cell_coords=((3778, 2744), (3774, 2890), (4017, 2891), (4018, 2744)),
# 	cell_location=(16, 16, 11, 11)
#
# 	cell_id=TableCell_1542010541897_3184,
# 	cell_coords=((4018, 2744), (4017, 2891), (4589, 2892), (4592, 2749)),
# 	cell_location=(16, 16, 12, 12)
#
# 	cell_id=TableCell_1542010827486_4476,
# 	cell_coords=((70, 2885), (72, 3035), (247, 3034), (246, 2887)),
# 	cell_location=(17, 17, 0, 0)
#
# 	cell_id=TableCell_1542010827486_4474,
# 	cell_coords=((246, 2887), (247, 3034), (356, 3034), (355, 2888)),
# 	cell_location=(17, 17, 1, 1)
#
# 	cell_id=TableCell_1542010820778_4386,
# 	cell_coords=((355, 2888), (356, 3034), (1203, 3024), (1203, 2888)),
# 	cell_location=(17, 17, 2, 2)
#
# 	cell_id=TableCell_1542010812557_4298,
# 	cell_coords=((1203, 2888), (1203, 3024), (1706, 3016), (1706, 2885)),
# 	cell_location=(17, 17, 3, 3)
#
# 	cell_id=TableCell_1542010601973_3892,
# 	cell_coords=((1706, 2885), (1706, 3016), (2083, 3012), (2083, 2885)),
# 	cell_location=(17, 17, 4, 4)
#
# 	cell_id=TableCell_1542010593206_3804,
# 	cell_coords=((2083, 2885), (2083, 3012), (2329, 3013), (2329, 2888)),
# 	cell_location=(17, 17, 5, 5)
#
# 	cell_id=TableCell_1542010584204_3716,
# 	cell_coords=((2329, 2888), (2329, 3013), (2773, 3006), (2774, 2886)),
# 	cell_location=(17, 17, 6, 6)
#
# 	cell_id=TableCell_1542010577200_3628,
# 	cell_coords=((2774, 2886), (2773, 3006), (3256, 3001), (3258, 2887)),
# 	cell_location=(17, 17, 7, 7)
#
# 	cell_id=TableCell_1542010571444_3540,
# 	cell_coords=((3258, 2887), (3256, 3001), (3442, 3000), (3444, 2888)),
# 	cell_location=(17, 17, 8, 8)
#
# 	cell_id=TableCell_1542010564689_3452,
# 	cell_coords=((3444, 2888), (3442, 3000), (3609, 2999), (3610, 2889)),
# 	cell_location=(17, 17, 9, 9)
#
# 	cell_id=TableCell_1542010556624_3364,
# 	cell_coords=((3610, 2889), (3609, 2999), (3772, 2998), (3774, 2890)),
# 	cell_location=(17, 17, 10, 10)
#
# 	cell_id=TableCell_1542010551398_3276,
# 	cell_coords=((3774, 2890), (3772, 2998), (4015, 2996), (4017, 2891)),
# 	cell_location=(17, 17, 11, 11)
#
# 	cell_id=TableCell_1542010541913_3188,
# 	cell_coords=((4017, 2891), (4015, 2996), (4587, 2991), (4589, 2892)),
# 	cell_location=(17, 17, 12, 12)
#
# 	cell_id=TableCell_1542010827533_4480,
# 	cell_coords=((72, 3035), (76, 3241), (243, 3241), (247, 3034)),
# 	cell_location=(18, 18, 0, 0)
#
# 	cell_id=TableCell_1542010827533_4478,
# 	cell_coords=((247, 3034), (243, 3241), (354, 3241), (356, 3034)),
# 	cell_location=(18, 18, 1, 1)
#
# 	cell_id=TableCell_1542010820825_4390,
# 	cell_coords=((356, 3034), (354, 3241), (1203, 3243), (1203, 3024)),
# 	cell_location=(18, 18, 2, 2)
#
# 	cell_id=TableCell_1542010812604_4302,
# 	cell_coords=((1203, 3024), (1203, 3243), (1704, 3243), (1706, 3016)),
# 	cell_location=(18, 18, 3, 3)
#
# 	cell_id=TableCell_1542010602020_3896,
# 	cell_coords=((1706, 3016), (1704, 3243), (2082, 3241), (2083, 3012)),
# 	cell_location=(18, 18, 4, 4)
#
# 	cell_id=TableCell_1542010593237_3808,
# 	cell_coords=((2083, 3012), (2082, 3241), (2331, 3241), (2329, 3013)),
# 	cell_location=(18, 18, 5, 5)
#
# 	cell_id=TableCell_1542010584251_3720,
# 	cell_coords=((2329, 3013), (2331, 3241), (2772, 3241), (2773, 3006)),
# 	cell_location=(18, 18, 6, 6)
#
# 	cell_id=TableCell_1542010577231_3632,
# 	cell_coords=((2773, 3006), (2772, 3241), (3257, 3241), (3256, 3001)),
# 	cell_location=(18, 18, 7, 7)
#
# 	cell_id=TableCell_1542010571459_3544,
# 	cell_coords=((3256, 3001), (3257, 3241), (3440, 3240), (3442, 3000)),
# 	cell_location=(18, 18, 8, 8)
#
# 	cell_id=TableCell_1542010564704_3456,
# 	cell_coords=((3442, 3000), (3440, 3240), (3606, 3241), (3609, 2999)),
# 	cell_location=(18, 18, 9, 9)
#
# 	cell_id=TableCell_1542010556655_3368,
# 	cell_coords=((3609, 2999), (3606, 3241), (3770, 3241), (3772, 2998)),
# 	cell_location=(18, 18, 10, 10)
#
# 	cell_id=TableCell_1542010551413_3280,
# 	cell_coords=((3772, 2998), (3770, 3241), (4012, 3241), (4015, 2996)),
# 	cell_location=(18, 18, 11, 11)
#
# 	cell_id=TableCell_1542010541928_3192,
# 	cell_coords=((4015, 2996), (4012, 3241), (4582, 3241), (4587, 2991)),
# 	cell_location=(18, 18, 12, 12)
#
# 	cell_id=TableCell_1542010827580_4484,
# 	cell_coords=((76, 3241), (79, 3400), (243, 3399), (243, 3241)),
# 	cell_location=(19, 19, 0, 0)
#
# 	cell_id=TableCell_1542010827580_4482,
# 	cell_coords=((243, 3241), (243, 3399), (355, 3399), (354, 3241)),
# 	cell_location=(19, 19, 1, 1)
#
# 	cell_id=TableCell_1542010820872_4394,
# 	cell_coords=((354, 3241), (355, 3399), (1203, 3399), (1203, 3243)),
# 	cell_location=(19, 19, 2, 2)
#
# 	cell_id=TableCell_1542010812651_4306,
# 	cell_coords=((1203, 3243), (1203, 3399), (1704, 3399), (1704, 3243)),
# 	cell_location=(19, 19, 3, 3)
#
# 	cell_id=TableCell_1542010602066_3900,
# 	cell_coords=((1704, 3243), (1704, 3399), (2081, 3397), (2082, 3241)),
# 	cell_location=(19, 19, 4, 4)
#
# 	cell_id=TableCell_1542010593284_3812,
# 	cell_coords=((2082, 3241), (2081, 3397), (2330, 3397), (2331, 3241)),
# 	cell_location=(19, 19, 5, 5)
#
# 	cell_id=TableCell_1542010584282_3724,
# 	cell_coords=((2331, 3241), (2330, 3397), (2771, 3397), (2772, 3241)),
# 	cell_location=(19, 19, 6, 6)
#
# 	cell_id=TableCell_1542010577262_3636,
# 	cell_coords=((2772, 3241), (2771, 3397), (3255, 3397), (3257, 3241)),
# 	cell_location=(19, 19, 7, 7)
#
# 	cell_id=TableCell_1542010571490_3548,
# 	cell_coords=((3257, 3241), (3255, 3397), (3439, 3396), (3440, 3240)),
# 	cell_location=(19, 19, 8, 8)
#
# 	cell_id=TableCell_1542010564736_3460,
# 	cell_coords=((3440, 3240), (3439, 3396), (3604, 3397), (3606, 3241)),
# 	cell_location=(19, 19, 9, 9)
#
# 	cell_id=TableCell_1542010556670_3372,
# 	cell_coords=((3606, 3241), (3604, 3397), (3768, 3397), (3770, 3241)),
# 	cell_location=(19, 19, 10, 10)
#
# 	cell_id=TableCell_1542010551429_3284,
# 	cell_coords=((3770, 3241), (3768, 3397), (4010, 3397), (4012, 3241)),
# 	cell_location=(19, 19, 11, 11)
#
# 	cell_id=TableCell_1542010541944_3196,
# 	cell_coords=((4012, 3241), (4010, 3397), (4579, 3397), (4582, 3241)),
# 	cell_location=(19, 19, 12, 12)
#
# 	cell_id=TableCell_1542010827627_4488,
# 	cell_coords=((79, 3400), (80, 3482), (244, 3482), (243, 3399)),
# 	cell_location=(20, 20, 0, 0)
#
# 	cell_id=TableCell_1542010827627_4486,
# 	cell_coords=((243, 3399), (244, 3482), (353, 3480), (355, 3399)),
# 	cell_location=(20, 20, 1, 1)
#
# 	cell_id=TableCell_1542010820919_4398,
# 	cell_coords=((355, 3399), (353, 3480), (1204, 3482), (1203, 3399)),
# 	cell_location=(20, 20, 2, 2)
#
# 	cell_id=TableCell_1542010812682_4310,
# 	cell_coords=((1203, 3399), (1204, 3482), (1704, 3482), (1704, 3399)),
# 	cell_location=(20, 20, 3, 3)
#
# 	cell_id=TableCell_1542010602098_3904,
# 	cell_coords=((1704, 3399), (1704, 3482), (2078, 3488), (2081, 3397)),
# 	cell_location=(20, 20, 4, 4)
#
# 	cell_id=TableCell_1542010593315_3816,
# 	cell_coords=((2081, 3397), (2078, 3488), (2327, 3488), (2330, 3397)),
# 	cell_location=(20, 20, 5, 5)
#
# 	cell_id=TableCell_1542010584314_3728,
# 	cell_coords=((2330, 3397), (2327, 3488), (2771, 3483), (2771, 3397)),
# 	cell_location=(20, 20, 6, 6)
#
# 	cell_id=TableCell_1542010577294_3640,
# 	cell_coords=((2771, 3397), (2771, 3483), (3254, 3484), (3255, 3397)),
# 	cell_location=(20, 20, 7, 7)
#
# 	cell_id=TableCell_1542010571522_3552,
# 	cell_coords=((3255, 3397), (3254, 3484), (3438, 3488), (3439, 3396)),
# 	cell_location=(20, 20, 8, 8)
#
# 	cell_id=TableCell_1542010564751_3464,
# 	cell_coords=((3439, 3396), (3438, 3488), (3606, 3489), (3604, 3397)),
# 	cell_location=(20, 20, 9, 9)
#
# 	cell_id=TableCell_1542010556686_3376,
# 	cell_coords=((3604, 3397), (3606, 3489), (3769, 3487), (3768, 3397)),
# 	cell_location=(20, 20, 10, 10)
#
# 	cell_id=TableCell_1542010551460_3288,
# 	cell_coords=((3768, 3397), (3769, 3487), (4011, 3488), (4010, 3397)),
# 	cell_location=(20, 20, 11, 11)
#
# 	cell_id=TableCell_1542010541960_3200,
# 	cell_coords=((4010, 3397), (4011, 3488), (4577, 3490), (4579, 3397)),
# 	cell_location=(20, 20, 12, 12)
#
# 	cell_id=TableCell_1542010827674_4492,
# 	cell_coords=((80, 3482), (85, 3675), (245, 3675), (244, 3482)),
# 	cell_location=(21, 21, 0, 0)
#
# 	cell_id=TableCell_1542010827674_4490,
# 	cell_coords=((244, 3482), (245, 3675), (354, 3673), (353, 3480)),
# 	cell_location=(21, 21, 1, 1)
#
# 	cell_id=TableCell_1542010820966_4402,
# 	cell_coords=((353, 3480), (354, 3673), (1204, 3676), (1204, 3482)),
# 	cell_location=(21, 21, 2, 2)
#
# 	cell_id=TableCell_1542010812729_4314,
# 	cell_coords=((1204, 3482), (1204, 3676), (1704, 3677), (1704, 3482)),
# 	cell_location=(21, 21, 3, 3)
#
# 	cell_id=TableCell_1542010602144_3908,
# 	cell_coords=((1704, 3482), (1704, 3677), (2077, 3684), (2078, 3488)),
# 	cell_location=(21, 21, 4, 4)
#
# 	cell_id=TableCell_1542010593346_3820,
# 	cell_coords=((2078, 3488), (2077, 3684), (2327, 3685), (2327, 3488)),
# 	cell_location=(21, 21, 5, 5)
#
# 	cell_id=TableCell_1542010584345_3732,
# 	cell_coords=((2327, 3488), (2327, 3685), (2770, 3680), (2771, 3483)),
# 	cell_location=(21, 21, 6, 6)
#
# 	cell_id=TableCell_1542010577325_3644,
# 	cell_coords=((2771, 3483), (2770, 3680), (3252, 3681), (3254, 3484)),
# 	cell_location=(21, 21, 7, 7)
#
# 	cell_id=TableCell_1542010571537_3556,
# 	cell_coords=((3254, 3484), (3252, 3681), (3435, 3685), (3438, 3488)),
# 	cell_location=(21, 21, 8, 8)
#
# 	cell_id=TableCell_1542010564782_3468,
# 	cell_coords=((3438, 3488), (3435, 3685), (3603, 3686), (3606, 3489)),
# 	cell_location=(21, 21, 9, 9)
#
# 	cell_id=TableCell_1542010556717_3380,
# 	cell_coords=((3606, 3489), (3603, 3686), (3766, 3684), (3769, 3487)),
# 	cell_location=(21, 21, 10, 10)
#
# 	cell_id=TableCell_1542010551476_3292,
# 	cell_coords=((3769, 3487), (3766, 3684), (4008, 3685), (4011, 3488)),
# 	cell_location=(21, 21, 11, 11)
#
# 	cell_id=TableCell_1542010541975_3204,
# 	cell_coords=((4011, 3488), (4008, 3685), (4575, 3687), (4577, 3490)),
# 	cell_location=(21, 21, 12, 12)

# %% [markdown]
# ```json
# ```
